# %% [markdown]
# # **Lab Analysis of Algorithms ExtraCredits**

# %% [markdown]
# ## **5. Fibonacci Number Again**
#
# In this problem, your goal is to compute 𝐹𝑛 modulo 𝑚, where 𝑛 may be really huge: up to 1018. For such values of 𝑛, an algorithm looping for 𝑛 iterations will not fit into one second for sure. Therefore we need to avoid such a loop.
#
# To get an idea how to solve this problem without going through all 𝐹𝑖 for 𝑖 from 0 to 𝑛, let’s see what happens when 𝑚 is small — say, 𝑚 = 2 or 𝑚 = 3.
#
# ![Pisano_periods.png](data:image/png;base64,...)
#
# Take a detailed look at this table. Do you see? Both these sequences are periodic! For 𝑚 = 2, the period
# is 011 and has length 3, while for 𝑚 = 3 the period is 01120221 and has length 8. Therefore, to compute,
# say, 𝐹2015 mod 3 we just need to find the remainder of 2015 when divided by 8. Since 2015 = 251 · 8 + 7, we
# conclude that 𝐹2015 mod 3 = 𝐹7 mod 3 = 1.
#
# This is true in general: for any integer 𝑚 ≥ 2, the sequence 𝐹𝑛 mod 𝑚 is periodic. The period always
# starts with 01 and is known as Pisano period.

# %% [markdown]
# ---
#
# ###**Problem Description**
#
# **Task.** Given two integers 𝑛 and 𝑚, output 𝐹𝑛 mod 𝑚 (that is, the remainder of 𝐹𝑛 when divided by 𝑚).
#
# **Input Format.** The input consists of two integers 𝑛 and 𝑚 given on the same line (separated by a space).
#
# **Constraints.** 1 ≤ 𝑛 ≤ 1018, 2 ≤ 𝑚 ≤ 103.
#
# **Output Format.** Output 𝐹𝑛 mod 𝑚.

# %% [markdown]
# **Sample testcase**
#
# ```python
# #run this sample testcase on a cell to help you validate your solution
#
# calc_fib_huge(239,1000)
# #𝐹_239 mod 1000 = 39679027332006820581608740953902289877834488152161 (mod 1000) = 161.
# #  --> Expected output: 161
#
# calc_fib_huge(2816213588,239)
# #  --> Expected output: 151
# ```
#
# ---

# %%
def longitud_pisano(m):
    
    pisano1 = 0
    pisano2 = 1
    for i in range(m * m):
        pisano1, pisano2 = pisano2, (pisano1 + pisano2) % m
        
        if (pisano1 == 0 and pisano2 == 1):
            return i + 1

def calc_fib_huge(n, m):
    
    n = n % longitud_pisano(m) 

    if (n <= 1):
        return n
    
    fibonacci = []
    fibonacci.append(0)
    fibonacci.append(1)
    for i in range(2,n+1):
        fibonacci.append((fibonacci[i - 1] + fibonacci[i - 2]) % m) 
    return fibonacci[-1]

# %%
calc_fib_huge(239,1000)
# Out:
# 161

# %%
calc_fib_huge(2816213588,239)
# Out:
# 151

# %% [markdown]
# #**|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||**#

# %% [markdown]
# ## **6. Last Digit of the Sum of Fibonacci Numbers**
#
# ![Sum_Fibonacci.png](data:image/png;base64,...)
#
# The goal in this problem is to find the last digit of a sum of the first 𝑛 Fibonacci numbers.

# %% [markdown]
# ---
#
# ###**Problem Description**
#
# **Task.** Given an integer 𝑛, find the last digit of the sum $𝐹_0 + 𝐹_1 + · · · + 𝐹_𝑛.$
#
# **Input Format.** The input consists of a single integer 𝑛.
#
# **Constraints.** 0 ≤ 𝑛 ≤ 1014.
#
# **Output Format.** Output the last digit of $𝐹_0 + 𝐹_1 + · · · + 𝐹_𝑛.$

# %% [markdown]
# **Sample testcase**
#
# ```python
# #run this sample testcase on a cell to help you validate your solution
#
# last_digit_sum_fibonacci(3)
# #𝐹_0 + 𝐹_1 + 𝐹_2 + 𝐹_3 = 0 + 1 + 1 + 2 = 4.
# #  --> Expected output: 4
#
# last_digit_sum_fibonacci(100)
# #𝐹_0 + ... + 𝐹_100 = 927372692193078999175.
# #  --> Expected output: 5
# ```
#
# ---

# %%
def last_digit_sum_fibonacci(n):

    if (n <= 1):
        return n
    
    n+=2
    n = n % 60
    
    fibonacci = []
    fibonacci.append(0)
    fibonacci.append(1)
    for i in range(2,n+1):
        fibonacci.append((fibonacci[i - 1] + fibonacci[i - 2]) % 10)
    
    if(fibonacci[-1] == 0):
        return 9
    
    return fibonacci[-1]-1

# %%
last_digit_sum_fibonacci(3)
# Out:
# 4

# %%
last_digit_sum_fibonacci(100)
# Out:
# 5

# %% [markdown]
# #**|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||**#

# %% [markdown]
# ## **7. Last Digit of the Sum of Fibonacci Numbers Again**
#
# ![Fibonacci_rabbits.png](data:image/png;base64,...)
#
# Now, we would like to find the last digit of a *partial* sum of Fibonacci numbers: 𝐹𝑚 + 𝐹𝑚+1 + · · · + 𝐹𝑛.

# %% [markdown]
# ---
#
# ###**Problem Description**
#
# **Task.** Given two non-negative integers 𝑚 and 𝑛, where 𝑚 ≤ 𝑛, find the last digit of the sum $𝐹_𝑚 + 𝐹_{𝑚+1} + · · · + 𝐹_𝑛.$
#
# **Input Format.** The input consists of two non-negative integers 𝑚 and 𝑛 separated by a space.
#
# **Constraints.** 0 ≤ 𝑚 ≤ 𝑛 ≤ 1014.
#
# **Output Format.** Output the last digit of $𝐹_𝑚 + 𝐹_{𝑚+1} + · · · + 𝐹_𝑛.$

# %% [markdown]
# **Sample testcase**
#
# ```python
# #run this sample testcase on a cell to help you validate your solution
#
# partial_sum_fibonacci(3,7)
# #𝐹_3 + 𝐹_4 + 𝐹_5 + 𝐹_6 + 𝐹_7 = 2 + 3 + 5 + 8 + 13 = 31.
# #  --> Expected output: 1
#
# partial_sum_fibonacci(10,10)
# #𝐹_10 = 55.
# #  --> Expected output: 5
#
# partial_sum_fibonacci(10,200)
# #𝐹_10 + 𝐹_11 + ... + 𝐹_200 =  734544867157818093234908902110449296423262.
# #  --> Expected output: 2
# ```
#
# ---

# %%
def partial_sum_fibonacci(m,n):

    if (n <= 1 and m <= 1):
        return n
    
    n+=2
    n = n % 60

    m+=1
    m = m % 60
    
    fibonacci = []
    fibonacci.append(0)
    fibonacci.append(1)

    if(n >= m):
      max = n

    else: 
      max = m


    for i in range(2,max+1):
        fibonacci.append((fibonacci[i - 1] + fibonacci[i - 2])%10)
    
    sum = fibonacci[n] - fibonacci[m] + 10
    sum %= 10
    
    return sum

# %%
partial_sum_fibonacci(3,7)
# Out:
# 1

# %%
partial_sum_fibonacci(10,10)
# Out:
# 5

# %%
partial_sum_fibonacci(10,200)
# Out:
# 2

# %% [markdown]
# #**|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||**#

# %% [markdown]
# ## **8. Last Digit of the Sum of Squares of Fibonacci Numbers**
#
# Since the brute force search algorithm for this problem is too slow (𝑛 may be as large as 1018), we need to come
# up with a simple formula for $F^2_0 +F^2_1 + \dots +F^2_𝑛$.
#
# The figure below represents the sum $F^2_1 +F^2_2 +F^2_3 +F^2_4 +F^2_5$ as the area of a rectangle with vertical side $F_5 = 5$ and horizontal side $F_5 + F_4 = 3 + 5 = F_6$.
#
# ![Fib_squares.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
# ###**Problem Description**
#
# **Task.** Compute the last digit of $F^2_0 + F^2_1 + · · · + F^2_𝑛.$
#
# **Input Format.** Integer 𝑛.
#
# **Constraints.** 0 ≤ 𝑛 ≤ 1014.
#
# **Output Format.** The last digit of $F^2_0 + F^2_1 + · · · + F^2_𝑛.$

# %% [markdown]
# **Sample testcase**
#
# ```python
# #run this sample testcase on a cell to help you validate your solution
#
# sum_fibonacci_squares(7)
# #(𝐹_0)^2 + (𝐹_1)^2 + ... + (𝐹_7)^2 = 0 + 1 + 1 + 4 + 9 + 25 + 64 + 169 = 273.
# #  --> Expected output: 3
#
# sum_fibonacci_squares(73)
# #(𝐹_0)^2 + ... + (𝐹_73)^2 = 1052478208141359608061842155201.
# #  --> Expected output: 1
#
# sum_fibonacci_squares(1234567890)
# #  --> Expected output: 0
# ```
#
# ---

# %%
def sum_fibonacci_squares(n):

    if (n <= 1):
        return n

    n = n % 60
    
    fibonacci = []
    fibonacci.append(0)
    fibonacci.append(1)
    for i in range(2,n+2):
        fibonacci.append((fibonacci[i - 1] + fibonacci[i - 2])%10)
    
    return (fibonacci[n] * fibonacci[n+1])%10

# %%
sum_fibonacci_squares(7)
# Out:
# 3

# %%
sum_fibonacci_squares(73)
# Out:
# 1

# %%
sum_fibonacci_squares(1234567890)
# Out:
# 0

# %% [markdown]
# # **Coursera screenshots**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
